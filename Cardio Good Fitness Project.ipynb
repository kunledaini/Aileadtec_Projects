# %%
import pandas as pd  # We import pandas

df_cd = pd.read_csv("./cardiogoodfitness.csv") # I gave my data the name df_cd

# %%
df_cd
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     TM195   18    Male         14        Single      3        4   29562
# 1     TM195   19    Male         15        Single      2        3   31836
# 2     TM195   19  Female         14     Partnered      4        3   30699
# 3     TM195   19    Male         12        Single      3        3   32973
# 4     TM195   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   TM798   40    Male         21        Single      6        5   83416
# 176   TM798   42    Male         18        Single      5        4   89641
# 177   TM798   45    Male         16        Single      5        5   90886
# 178   TM798   47    Male         18     Partnered      4        5  104581
# 179   TM798   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 0      112
# 1       75
# 2       66
# 3       85
# 4       47
# ...

# %% [markdown]
# - To show information about my data

# %%
df_cd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %% [markdown]
# - 6 out of 9 columns have integers
# - There is no column with missing values
# - There are 180 rows and 9 columns

# %%
# The next thing is to describe the dataset

df_cd.describe(include = "all")
# Out:
#        Product         Age Gender   Education MaritalStatus       Usage  \
# count      180  180.000000    180  180.000000           180  180.000000
# unique       3         NaN      2         NaN             2         NaN
# top      TM195         NaN   Male         NaN     Partnered         NaN
# freq        80         NaN    104         NaN           107         NaN
# mean       NaN   28.788889    NaN   15.572222           NaN    3.455556
# std        NaN    6.943498    NaN    1.617055           NaN    1.084797
# min        NaN   18.000000    NaN   12.000000           NaN    2.000000
# 25%        NaN   24.000000    NaN   14.000000           NaN    3.000000
# 50%        NaN   26.000000    NaN   16.000000           NaN    3.000000
# 75%        NaN   33.000000    NaN   16.000000           NaN    4.000000
# max        NaN   50.000000    NaN   21.000000           NaN    7.000000
#
#            Fitness         Income       Miles
# count   180.000000     180.000000  180.000000
# ...

# %% [markdown]
# - Product

# %%
df_cd["Product"].unique()
# Out:
# array(['TM195', 'TM498', 'TM798'], dtype=object)

# %%
# To check for blank string in Product column

df_cd[(df_cd['Product'] == ' ')]
# Out:
# Empty DataFrame
# Columns: [Product, Age, Gender, Education, MaritalStatus, Usage, Fitness, Income, Miles]
# Index: []

# %% [markdown]
# - There are 3 distinct products of threadmill from the dataset above.
# - Of the three products, TM195 occured more and at 80 times.

# %% [markdown]
# - Age

# %% [markdown]
# - Minimum age is 18 and the maximum age is 50
# - The average is around 28

# %% [markdown]
# - Gender

# %%
df_cd["Gender"].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df_cd[(df_cd['Gender'] == ' ')]
# Out:
# Empty DataFrame
# Columns: [Product, Age, Gender, Education, MaritalStatus, Usage, Fitness, Income, Miles]
# Index: []

# %% [markdown]
# - There are more males than female in the dataset.
# - There are 104 males

# %% [markdown]
# - Education

# %% [markdown]
# - 12 years is the minimum number of years anybody spent having education.
# - 21 years is the maximum number of years anybody spent having education.
# - The average number of years anybody spent on education is 15 years.

# %% [markdown]
# - Marital Status

# %%
df_cd["MaritalStatus"].unique()
# Out:
# array(['Single', 'Partnered'], dtype=object)

# %% [markdown]
# - There are more Partnered in the dataset
# - 107 Partnered out of 180 customers

# %% [markdown]
# - Usage

# %% [markdown]
# - Minimum number of times anybody used the threadmill was twice a week.
# - The maximum number of times it was used was 7 times a week.
# - The average number of times the threadmill is used in a week is 3 times.

# %% [markdown]
# - Fitness

# %% [markdown]
# - The maximum fitness that could be achieved is 5
# - The minimum being 1

# %% [markdown]
# - Income

# %% [markdown]
# - The maximum income of any of the customers is 104581
# - The minimum income of any of the customers is 29562
# - The average income is 53719

# %% [markdown]
# - Miles

# %% [markdown]
# - The maximum number of miles covered by any customer is 360
# - The minimum number of miles covered by any cutomer is 21
# - The average number of miles is 103 miles

# %% [markdown]
# 1.
#
# Come up with a customer profile (characteristics of a customer) of the different products

# %%
# To get the customers who purchased the product TM195

df_cd[(df_cd["Product"] == "TM195")]
# Out:
#    Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0    TM195   18    Male         14        Single      3        4   29562
# 1    TM195   19    Male         15        Single      2        3   31836
# 2    TM195   19  Female         14     Partnered      4        3   30699
# 3    TM195   19    Male         12        Single      3        3   32973
# 4    TM195   20    Male         13     Partnered      4        2   35247
# ..     ...  ...     ...        ...           ...    ...      ...     ...
# 75   TM195   43    Male         16     Partnered      3        3   53439
# 76   TM195   44  Female         16        Single      3        4   57987
# 77   TM195   46  Female         16     Partnered      3        2   60261
# 78   TM195   47    Male         16     Partnered      4        3   56850
# 79   TM195   50  Female         16     Partnered      3        3   64809
#
#     Miles
# 0     112
# 1      75
# 2      66
# 3      85
# 4      47
# ..    ...
# ...

# %% [markdown]
# - 80 Customers in total purchased the product TM195

# %%
# Customers who are males who purchased the product TM195

df_cd[(df_cd["Product"] == "TM195") & (df_cd["Gender"] == "Male")]
# Out:
#    Product  Age Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0    TM195   18   Male         14        Single      3        4   29562    112
# 1    TM195   19   Male         15        Single      2        3   31836     75
# 3    TM195   19   Male         12        Single      3        3   32973     85
# 4    TM195   20   Male         13     Partnered      4        2   35247     47
# 7    TM195   21   Male         13        Single      3        3   32973     85
# 8    TM195   21   Male         15        Single      5        4   35247    141
# 10   TM195   22   Male         14        Single      3        3   36384     85
# 14   TM195   23   Male         16     Partnered      3        1   38658     47
# 15   TM195   23   Male         16     Partnered      3        3   40932     75
# 17   TM195   23   Male         16     Partnered      4        3   39795     94
# 20   TM195   23   Male         14        Single      4        3   38658    113
# ...

# %%
df_cd[(df_cd["Product"] == "TM195") & (df_cd["Gender"] == "Male")].count()
# Out:
# Product          40
# Age              40
# Gender           40
# Education        40
# MaritalStatus    40
# Usage            40
# Fitness          40
# Income           40
# Miles            40
# dtype: int64

# %% [markdown]
# - 40 Male Customers purchased the product TM195

# %%
# Customers who are females who purchased the product TM195

df_cd[(df_cd["Product"] == "TM195") & (df_cd["Gender"] == "Female")]
# Out:
#    Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 2    TM195   19  Female         14     Partnered      4        3   30699
# 5    TM195   20  Female         14     Partnered      3        3   32973
# 6    TM195   21  Female         14     Partnered      3        3   35247
# 9    TM195   21  Female         15     Partnered      2        3   37521
# 11   TM195   22  Female         14     Partnered      3        2   35247
# 12   TM195   22  Female         16        Single      4        3   36384
# 13   TM195   22  Female         14        Single      3        3   35247
# 16   TM195   23  Female         14        Single      2        3   34110
# 18   TM195   23  Female         16        Single      4        3   38658
# 19   TM195   23  Female         15     Partnered      2        2   34110
# 22   TM195   24  Female         16        Single      4        3   42069
# 23   TM195   24  Female         16     Partnered      5        5   44343
# ...

# %%
df_cd[(df_cd["Product"] == "TM195") & (df_cd["Gender"] == "Female")].count()
# Out:
# Product          40
# Age              40
# Gender           40
# Education        40
# MaritalStatus    40
# Usage            40
# Fitness          40
# Income           40
# Miles            40
# dtype: int64

# %% [markdown]
# - 40 Female Customers purchased the product TM195

# %%
# Defining the Customers who purchased the product TM195 by Marital Status - Single

df_cd[(df_cd["Product"] == "TM195") & (df_cd["MaritalStatus"] == "Single")]
# Out:
#    Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0    TM195   18    Male         14        Single      3        4   29562
# 1    TM195   19    Male         15        Single      2        3   31836
# 3    TM195   19    Male         12        Single      3        3   32973
# 7    TM195   21    Male         13        Single      3        3   32973
# 8    TM195   21    Male         15        Single      5        4   35247
# 10   TM195   22    Male         14        Single      3        3   36384
# 12   TM195   22  Female         16        Single      4        3   36384
# 13   TM195   22  Female         14        Single      3        3   35247
# 16   TM195   23  Female         14        Single      2        3   34110
# 18   TM195   23  Female         16        Single      4        3   38658
# 20   TM195   23    Male         14        Single      4        3   38658
# 21   TM195   23    Male         16        Single      4        3   40932
# ...

# %%
df_cd[(df_cd["Product"] == "TM195") & (df_cd["MaritalStatus"] == "Single")].count()
# Out:
# Product          32
# Age              32
# Gender           32
# Education        32
# MaritalStatus    32
# Usage            32
# Fitness          32
# Income           32
# Miles            32
# dtype: int64

# %% [markdown]
# - 32 Single Customers purchased the product TM195

# %%
# Defining the Customers who purchased the product TM195 by Marital Status - Partnered

df_cd[(df_cd["Product"] == "TM195") & (df_cd["MaritalStatus"] == "Partnered")]
# Out:
#    Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 2    TM195   19  Female         14     Partnered      4        3   30699
# 4    TM195   20    Male         13     Partnered      4        2   35247
# 5    TM195   20  Female         14     Partnered      3        3   32973
# 6    TM195   21  Female         14     Partnered      3        3   35247
# 9    TM195   21  Female         15     Partnered      2        3   37521
# 11   TM195   22  Female         14     Partnered      3        2   35247
# 14   TM195   23    Male         16     Partnered      3        1   38658
# 15   TM195   23    Male         16     Partnered      3        3   40932
# 17   TM195   23    Male         16     Partnered      4        3   39795
# 19   TM195   23  Female         15     Partnered      2        2   34110
# 23   TM195   24  Female         16     Partnered      5        5   44343
# 25   TM195   24    Male         13     Partnered      3        2   42069
# ...

# %%
df_cd[(df_cd["Product"] == "TM195") & (df_cd["MaritalStatus"] == "Partnered")].count()
# Out:
# Product          48
# Age              48
# Gender           48
# Education        48
# MaritalStatus    48
# Usage            48
# Fitness          48
# Income           48
# Miles            48
# dtype: int64

# %% [markdown]
# - 48 Partnered Customers purchased the product TM195

# %%
# To get the customers who purchased the product TM498

df_cd[(df_cd["Product"] == "TM498")]
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 80    TM498   19    Male         14        Single      3        3   31836
# 81    TM498   20    Male         14        Single      2        3   32973
# 82    TM498   20  Female         14     Partnered      3        3   34110
# 83    TM498   20    Male         14        Single      3        3   38658
# 84    TM498   21  Female         14     Partnered      5        4   34110
# 85    TM498   21    Male         16     Partnered      2        2   34110
# 86    TM498   21    Male         12     Partnered      2        2   32973
# 87    TM498   23    Male         14     Partnered      3        3   36384
# 88    TM498   23    Male         14     Partnered      3        3   38658
# 89    TM498   23  Female         16        Single      3        3   45480
# 90    TM498   23    Male         16     Partnered      4        3   45480
# 91    TM498   23  Female         16     Partnered      3        2   43206
# ...

# %%
df_cd[(df_cd["Product"] == "TM498")].count()
# Out:
# Product          60
# Age              60
# Gender           60
# Education        60
# MaritalStatus    60
# Usage            60
# Fitness          60
# Income           60
# Miles            60
# dtype: int64

# %% [markdown]
# - 60 Customers purchased the product TM498

# %%
# Customers who are males who purchased the product TM498

df_cd[(df_cd["Product"] == "TM498") & (df_cd["Gender"] == "Male")]
# Out:
#     Product  Age Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 80    TM498   19   Male         14        Single      3        3   31836
# 81    TM498   20   Male         14        Single      2        3   32973
# 83    TM498   20   Male         14        Single      3        3   38658
# 85    TM498   21   Male         16     Partnered      2        2   34110
# 86    TM498   21   Male         12     Partnered      2        2   32973
# 87    TM498   23   Male         14     Partnered      3        3   36384
# 88    TM498   23   Male         14     Partnered      3        3   38658
# 90    TM498   23   Male         16     Partnered      4        3   45480
# 93    TM498   23   Male         16     Partnered      3        3   45480
# 95    TM498   24   Male         14        Single      3        4   48891
# 99    TM498   25   Male         16     Partnered      2        2   52302
# 101   TM498   25   Male         14        Single      3        3   45480
# ...

# %%
df_cd[(df_cd["Product"] == "TM498") & (df_cd["Gender"] == "Male")].count()
# Out:
# Product          31
# Age              31
# Gender           31
# Education        31
# MaritalStatus    31
# Usage            31
# Fitness          31
# Income           31
# Miles            31
# dtype: int64

# %% [markdown]
# - 31 Male Customers purchased the product TM498

# %%
# Customers who are females who purchased the product TM498

df_cd[(df_cd["Product"] == "TM498") & (df_cd["Gender"] == "Female")]
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 82    TM498   20  Female         14     Partnered      3        3   34110
# 84    TM498   21  Female         14     Partnered      5        4   34110
# 89    TM498   23  Female         16        Single      3        3   45480
# 91    TM498   23  Female         16     Partnered      3        2   43206
# 92    TM498   23  Female         14        Single      3        2   40932
# 94    TM498   24  Female         14        Single      3        2   40932
# 96    TM498   24  Female         16        Single      3        3   50028
# 97    TM498   25  Female         14     Partnered      2        3   45480
# 98    TM498   25  Female         14        Single      3        4   43206
# 100   TM498   25  Female         14     Partnered      5        3   47754
# 102   TM498   25  Female         14        Single      2        3   43206
# 106   TM498   25  Female         14        Single      2        2   45480
# ...

# %%
df_cd[(df_cd["Product"] == "TM498") & (df_cd["Gender"] == "Female")].count()
# Out:
# Product          29
# Age              29
# Gender           29
# Education        29
# MaritalStatus    29
# Usage            29
# Fitness          29
# Income           29
# Miles            29
# dtype: int64

# %% [markdown]
# - 29 Female Customers purchased the product TM498

# %%
# Defining the Customers who purchased the product TM498 by Marital Status - Single

df_cd[(df_cd["Product"] == "TM498") & (df_cd["MaritalStatus"] == "Single")]
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 80    TM498   19    Male         14        Single      3        3   31836
# 81    TM498   20    Male         14        Single      2        3   32973
# 83    TM498   20    Male         14        Single      3        3   38658
# 89    TM498   23  Female         16        Single      3        3   45480
# 92    TM498   23  Female         14        Single      3        2   40932
# 94    TM498   24  Female         14        Single      3        2   40932
# 95    TM498   24    Male         14        Single      3        4   48891
# 96    TM498   24  Female         16        Single      3        3   50028
# 98    TM498   25  Female         14        Single      3        4   43206
# 101   TM498   25    Male         14        Single      3        3   45480
# 102   TM498   25  Female         14        Single      2        3   43206
# 106   TM498   25  Female         14        Single      2        2   45480
# ...

# %%
# The Single Customers who purchased TM498

df_cd[(df_cd["Product"] == "TM498") & (df_cd["MaritalStatus"] == "Single")].count()
# Out:
# Product          24
# Age              24
# Gender           24
# Education        24
# MaritalStatus    24
# Usage            24
# Fitness          24
# Income           24
# Miles            24
# dtype: int64

# %% [markdown]
# - 24 Single Customers who purchased the product TM498

# %%
# Defining the Customers who purchased the product TM498 by Marital Status - Partnered

df_cd[(df_cd["Product"] == "TM498") & (df_cd["MaritalStatus"] == "Partnered")]
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 82    TM498   20  Female         14     Partnered      3        3   34110
# 84    TM498   21  Female         14     Partnered      5        4   34110
# 85    TM498   21    Male         16     Partnered      2        2   34110
# 86    TM498   21    Male         12     Partnered      2        2   32973
# 87    TM498   23    Male         14     Partnered      3        3   36384
# 88    TM498   23    Male         14     Partnered      3        3   38658
# 90    TM498   23    Male         16     Partnered      4        3   45480
# 91    TM498   23  Female         16     Partnered      3        2   43206
# 93    TM498   23    Male         16     Partnered      3        3   45480
# 97    TM498   25  Female         14     Partnered      2        3   45480
# 99    TM498   25    Male         16     Partnered      2        2   52302
# 100   TM498   25  Female         14     Partnered      5        3   47754
# ...

# %%
df_cd[(df_cd["Product"] == "TM498") & (df_cd["MaritalStatus"] == "Partnered")].count()
# Out:
# Product          36
# Age              36
# Gender           36
# Education        36
# MaritalStatus    36
# Usage            36
# Fitness          36
# Income           36
# Miles            36
# dtype: int64

# %% [markdown]
# - 36 Partnered Customers purchased the product TM498

# %%
# To get the customers who purchased the product TM798

df_cd[(df_cd["Product"] == "TM798")]
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 140   TM798   22    Male         14        Single      4        3   48658
# 141   TM798   22    Male         16        Single      3        5   54781
# 142   TM798   22    Male         18        Single      4        5   48556
# 143   TM798   23    Male         16        Single      4        5   58516
# 144   TM798   23  Female         18        Single      5        4   53536
# 145   TM798   23    Male         16        Single      4        5   48556
# 146   TM798   24    Male         16        Single      4        5   61006
# 147   TM798   24    Male         18     Partnered      4        5   57271
# 148   TM798   24  Female         16        Single      5        5   52291
# 149   TM798   24    Male         16        Single      5        5   49801
# 150   TM798   25    Male         16     Partnered      4        5   49801
# 151   TM798   25    Male         16     Partnered      4        4   62251
# ...

# %%
df_cd[(df_cd["Product"] == "TM798")].count()
# Out:
# Product          40
# Age              40
# Gender           40
# Education        40
# MaritalStatus    40
# Usage            40
# Fitness          40
# Income           40
# Miles            40
# dtype: int64

# %% [markdown]
# - 40 Customers who purchased TM798

# %%
# Customers who are males who purchased the product TM798

df_cd[(df_cd["Product"] == "TM798") & (df_cd["Gender"] == "Male")]
# Out:
#     Product  Age Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 140   TM798   22   Male         14        Single      4        3   48658
# 141   TM798   22   Male         16        Single      3        5   54781
# 142   TM798   22   Male         18        Single      4        5   48556
# 143   TM798   23   Male         16        Single      4        5   58516
# 145   TM798   23   Male         16        Single      4        5   48556
# 146   TM798   24   Male         16        Single      4        5   61006
# 147   TM798   24   Male         18     Partnered      4        5   57271
# 149   TM798   24   Male         16        Single      5        5   49801
# 150   TM798   25   Male         16     Partnered      4        5   49801
# 151   TM798   25   Male         16     Partnered      4        4   62251
# 153   TM798   25   Male         18     Partnered      4        3   64741
# 154   TM798   25   Male         18     Partnered      6        4   70966
# ...

# %%
df_cd[(df_cd["Product"] == "TM798") & (df_cd["Gender"] == "Male")].count()
# Out:
# Product          33
# Age              33
# Gender           33
# Education        33
# MaritalStatus    33
# Usage            33
# Fitness          33
# Income           33
# Miles            33
# dtype: int64

# %% [markdown]
# - 33 Male purchased the product TM798

# %%
# Customers who are females who purchased the product TM798

df_cd[(df_cd["Product"] == "TM798") & (df_cd["Gender"] == "Female")]
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 144   TM798   23  Female         18        Single      5        4   53536
# 148   TM798   24  Female         16        Single      5        5   52291
# 152   TM798   25  Female         18     Partnered      5        5   61006
# 157   TM798   26  Female         21        Single      4        3   69721
# 162   TM798   28  Female         18     Partnered      6        5   92131
# 167   TM798   30  Female         16     Partnered      6        5   90886
# 171   TM798   33  Female         18     Partnered      4        5   95866
#
#      Miles
# 144    100
# 148    200
# 152    200
# 157    100
# 162    180
# 167    280
# 171    200

# %%
# To get the number of Females who purchased TM798

df_cd[(df_cd["Product"] == "TM798") & (df_cd["Gender"] == "Female")].count()
# Out:
# Product          7
# Age              7
# Gender           7
# Education        7
# MaritalStatus    7
# Usage            7
# Fitness          7
# Income           7
# Miles            7
# dtype: int64

# %% [markdown]
# - 7 Females purchased the product TM798

# %%
# Defining the Customers who purchased the product TM798 by Marital Status - Single

df_cd[(df_cd["Product"] == "TM798") & (df_cd["MaritalStatus"] == "Single")]
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 140   TM798   22    Male         14        Single      4        3   48658
# 141   TM798   22    Male         16        Single      3        5   54781
# 142   TM798   22    Male         18        Single      4        5   48556
# 143   TM798   23    Male         16        Single      4        5   58516
# 144   TM798   23  Female         18        Single      5        4   53536
# 145   TM798   23    Male         16        Single      4        5   48556
# 146   TM798   24    Male         16        Single      4        5   61006
# 148   TM798   24  Female         16        Single      5        5   52291
# 149   TM798   24    Male         16        Single      5        5   49801
# 157   TM798   26  Female         21        Single      4        3   69721
# 160   TM798   27    Male         18        Single      4        3   88396
# 164   TM798   28    Male         18        Single      6        5   88396
# ...

# %%
# Numbers of Singles Customers who purchased TM798

df_cd[(df_cd["Product"] == "TM798") & (df_cd["MaritalStatus"] == "Single")].count()
# Out:
# Product          17
# Age              17
# Gender           17
# Education        17
# MaritalStatus    17
# Usage            17
# Fitness          17
# Income           17
# Miles            17
# dtype: int64

# %% [markdown]
# - 17 Single Customers who purchased the product TM798

# %%
# Defining the Customers who purchased the product TM798 by Marital Status - Partnered

df_cd[(df_cd["Product"] == "TM798") & (df_cd["MaritalStatus"] == "Partnered")]
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 147   TM798   24    Male         18     Partnered      4        5   57271
# 150   TM798   25    Male         16     Partnered      4        5   49801
# 151   TM798   25    Male         16     Partnered      4        4   62251
# 152   TM798   25  Female         18     Partnered      5        5   61006
# 153   TM798   25    Male         18     Partnered      4        3   64741
# 154   TM798   25    Male         18     Partnered      6        4   70966
# 155   TM798   25    Male         18     Partnered      6        5   75946
# 156   TM798   25    Male         20     Partnered      4        5   74701
# 158   TM798   26    Male         16     Partnered      5        4   64741
# 159   TM798   27    Male         16     Partnered      4        5   83416
# 161   TM798   27    Male         21     Partnered      4        4   90886
# 162   TM798   28  Female         18     Partnered      6        5   92131
# ...

# %%
# Numbers of Partnered Customers who purchased TM798

df_cd[(df_cd["Product"] == "TM798") & (df_cd["MaritalStatus"] == "Partnered")].count()
# Out:
# Product          23
# Age              23
# Gender           23
# Education        23
# MaritalStatus    23
# Usage            23
# Fitness          23
# Income           23
# Miles            23
# dtype: int64

# %% [markdown]
# - 23 of Partnered customers purchased the product TM798

# %% [markdown]
# 2.
#
# Perform univariate and multivariate analyses

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# To visualize the Product using Catplot

sns.catplot(x='Product', data=df_cd, kind='count')
plt.title("Categorical Plot of Product")
plt.xlabel("Products - Threadmill")
plt.show()

# %% [markdown]
# - The above shows how the products are distributed abong the customers
# - TM195 being used by 80 customers, TM498 by 60 and TM798 by 40

# %%
# To visualize the column Age using histogram

sns.histplot(x='Age', data=df_cd)
plt.title('Histogram of Age')
plt.xlabel('Age')
plt.show()

# %% [markdown]
# - From the above, it shows that there are not many customers who fall between ages from 42 to 50 years of age
# - We have more customers from 22 years of age to 36

# %%
# Plotting a Multivarate

sns.boxplot(x='Product', y='Age', data=df_cd)
plt.title("Plot of Products vs Age")
plt.xlabel('Products')
plt.ylabel('Age')
plt.show()

# %% [markdown]
# - From above, the average age of customers who went for TM195 and TM498 which are almost the same is around 26 years of age
# - TM798 having the average age around 27
# - We can also see that the more older customers went for the first two products than they did for the last product
# - Overall, fewer customers went for the TM798

# %%
sns.histplot(binwidth=1,x='Product', hue='Gender', data=df_cd, stat="count", multiple="dodge")
plt.title("Plot of Products vs Gender")
plt.xlabel('Products')
plt.ylabel('Gender')
plt.show()

# %% [markdown]
# - From above, it shows that Male and Female went for the TM195 product almost equally.
# - It is different with other 2 products

# %% [markdown]
# 3.
#
# Generate a set of insights and recommendations that will help the company in targeting new customers.

# %% [markdown]
# - The company should produce more TM195 since more customer go for it
# - The age group that should be most targeted is around 20 and 36, more advert can target this age range
